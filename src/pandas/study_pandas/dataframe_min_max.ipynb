# %%
import pandas as pd

# %%
df = pd.read_excel("./data/sample1.xlsx", engine='openpyxl', index_col=0)

# %%
df.mean(axis="columns") #行ごとの平均
# Out:
# pin
# P1    1.333333
# P2    2.666667
# P3    4.000000
# P4    1.666667
# dtype: float64

# %%
df["avg"] = df.mean(axis="columns")
df["max"] = df.max(axis="columns")
df["min"] = df.min(axis="columns")

# %%
ax = df.plot()
