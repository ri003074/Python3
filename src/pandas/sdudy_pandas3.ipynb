# %%
import csv
import re
from collections import OrderedDict

import matplotlib.pyplot as plt

import pandas as pd

# %%
with open("./data/wavedata4.csv", mode="r", encoding="utf-8-sig") as csvfile:
    reader = csv.reader(csvfile)
    data = []
    index = []
    for rows in reader:
        dic = OrderedDict()
        for i in range(0, len(rows), 2):
            try:
                dic[rows[i]] = float(rows[i + 1])
            except ValueError:
                dic[rows[i]] = rows[i + 1]
        data.append(dic)

# %%
df = pd.DataFrame(data)
df = df.set_index("condition")

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(1, 1, 1)

# fig.subplots_adjust(left=0.1, right=0.8)
# ax.set_xticklabels(rotation=45)
# fig.autofmt_xdate(rotation=45)
ax.set_xticks([0, 1])
df.plot(ax=ax)
plt.savefig("aaaaaaa.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure()
plt.plot(x, y)
plt.subplots_adjust(left=0, right=0.8, bottom=0, top=1)
plt.savefig("result.png", facecolor="azure")

# %%
with open("./data/wavedata5.csv", mode="r", encoding="utf-8-sig") as csvfile:
    reader = csv.reader(csvfile)
    for rows in reader:
        match = re.match(r"(.*)_(.*)_(.*)", rows[0])
        if match:
            rows.insert(0, "pin")
            rows.insert(1, match.group(1))
            rows.insert(2, "vihlt")
            rows.insert(3, match.group(2))
            rows.insert(4, "rate")
            rows.insert(5, match.group(3))
            rows.insert(6, "condition")
        else:
            print("something is wrong")
        print(rows)
# Out:
# ['pin', 'P771A1', 'vihlt', 'vih1vil0vt0', 'rate', 'rate250ps', 'condition', 'P771A1_vih1vil0vt0_rate250ps', 'duty', '51']
# ['pin', 'P772A1', 'vihlt', 'vih1vil0vt0', 'rate', 'rate250ps', 'condition', 'P772A1_vih1vil0vt0_rate250ps', 'duty', '52']

# %%
# Out:
# '1.5'
