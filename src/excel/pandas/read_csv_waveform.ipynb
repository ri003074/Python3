# %%
import csv
from collections import OrderedDict

import matplotlib.pyplot as plt

import pandas as pd

with open("data/wavedata.csv", mode="r", encoding="utf-8") as inp:
    reader = csv.reader(inp)
    data = []
    columns = []
    for rows in reader:
        print(rows)
        dic = OrderedDict()
        columns.append(rows[0])
        for i in range(1, len(rows) - 1, 2):
            dic[rows[i]] = float(rows[i + 1])
        data.append(dic)

_df = pd.DataFrame(data, index=columns)
# Out:
# ['\ufeffp1', 'tr', '41', 'tf', '44', 'duty', '51']
# ['p2', 'tr', '42', 'tf', '44', 'duty', '52']
# ['p3', 'tr', '43', 'tf', '45', 'duty', '51']

# %%
# Out:
#        tr    tf  duty
# ﻿p1  41.0  44.0  51.0
# p2   42.0  44.0  52.0
# p3   43.0  45.0  51.0

# %%
for col in df.columns:
    df = df[[col]]
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1)
    _df.plot(ax=ax)
    plt.savefig(col + ".png")
#     _df.plot(figsize=(10, 5), kind="line", legend=True, grid=False, style=["bo"])
#     plt.savefig(col + ".png")
#     plt.show()

# %%
df = df[["tr"]].plot()

# %%
df
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(10, 5), kind="line", legend=True, style=["bo"])
# Out:
# []
