# %%
import csv
from collections import OrderedDict

import matplotlib.pyplot as plt

import pandas as pd

with open("data/wavedata.csv", mode="r") as inp:
    reader = csv.reader(inp)
    data = []
    columns = []
    for rows in reader:
        print(rows)
        dic = OrderedDict()
        columns.append(rows[0])
        for i in range(1, len(rows) - 1, 2):
            dic[rows[i]] = float(rows[i + 1])
        data.append(dic)

df = pd.DataFrame(data, index=columns)
# Out:
# ['\ufeffp1', 'tr', '40', 'tf', '50', 'duty', '48.2']
# ['p2', 'tr', '41', 'tf', '51', 'duty', '49.9']
# ['p3', 'tr', '42', 'tf', '52', 'duty', '50.1']

# %%
df
# Out:
#        tr    tf  duty
# ﻿p1  40.0  50.0  48.2
# p2   41.0  51.0  49.9
# p3   42.0  52.0  50.1

# %%
for col in df.columns:
    _df = df[[col]]
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1)
    _df.plot(ax=ax)
    plt.savefig(col + ".png")
#     _df.plot(figsize=(10, 5), kind="line", legend=True, grid=False, style=["bo"])
#     plt.savefig(col + ".png")
#     plt.show()

# %%
df = df[["tr"]].plot()

# %%
df
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(10, 5), kind="line", legend=True, style=["bo"])
# Out:
# []
